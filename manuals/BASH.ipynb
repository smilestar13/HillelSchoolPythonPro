# %% [markdown]
# # Что такое bash?
#
#
# **Оболочка, или шелл (shell)** — это программа, в нашем случае названная «bash», что является сокращением от *Bourne Again Shell*.
#
# * Оболочка принимает ваши команды и передаёт их операционной системе. Для взаимодействия с системой используются терминалы, такие как gnome-terminal, eterm, nxterm и т. п.
#
# ## Основные команды
#
# * `pwd` - Сокращение от print working directory. Отображает папку (директорию) где мы сейчас находимся
# * `cd` - Позволяет перейти в новую папку
# * `mkdir` - Создает новую папку в текущей директории
# * `ls` - Выводит содержимое текущего каталога
# * `echo` - Консольный аналог print
# * `cat` - Считывает переданный файл и выводит по стандартному каналу вывода
# * `history` - Выводит историю использованных команд
# * `chmod` - Изменяет права доступа к файлу
# * `sudo` - Выполнение любой последующей команды с правами root-пользователя
# * `rm` - Удаление файла или директории
#
#
# ## CD
#
# * `cd` или `cd ~` - Перемещение в домашний каталог
# * `cd ..` - Переход на уровень выше
# * `cd -` - Возвращает в предыдущую папку
# * `cd my_dir` - Перемещает в папку my_dir (если она лежит в текущей директории)
# * `cd ~/my_dir` - Перемещает в папку my_dir (если не знаем точный путь)
#
#
# ## Права доступа
#
# * Команда `ls -l` выводит много информации о правах доступа к каждому файлу. Разберемся, какие они бывают:
#
# ### Цифровая запись   /Буквенная запись   /Права
# * «0» `---` Ничего не разрешено
# * 1 `--x` Исполнение
# * 2 `-w-` Запись
# * 3 `-wx` Запись и исполнение
# * 4 `r--` Чтение
# * 5 `r-x` Чтение и исполнение
# * 6 `rw-` Чтение и запись
# * 7 `rwx` Чтение, запись и исполнение
#
#
# ## Пример вывода доступов по ролям:
#
# ### Цифровая   /Буквенная   /Владелец   /Группа   /Все остальные
# * 755 `rwxr-xr-x` полный доступ   /чтение и исполнение   /чтение и исполнение
# * 644 `rw-r--r--` запись и чтение   /только чтение   /только чтение
# * 555 `r-xr-xr-x` чтение и исполнение   /чтение и исполнение   /чтение и исполнение
#
# ## CHMOD
# *У команды есть флаги, которые позволяют указать, для какой роли меняем доступы:*
# * `u` - владелец
# * `g` - группа
# * `o` - прочие пользователи
# * `a` - все.
#
# Вы можете вызвать chmod с описанием действий над конкретным файлом. Символ - обозначает удаление прав, символ + — добавление.
#
# Статья для новичков: https://proglib.io/p/bash-commands-for-beginners
